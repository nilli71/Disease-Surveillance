# %%
# %sql
CREATE DATABASE IF NOT EXISTS disease_surveillance;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- List all databases to confirm
SHOW DATABASES;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>default</td></tr><tr><td>disease_surveillance</td></tr><tr><td>diseasesurveillancedb</td></tr><tr><td>information_schema</td></tr></tbody></table></div>

# %%
# %sql
-- Use the new database
USE disease_surveillance;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Create the Patients table
CREATE TABLE IF NOT EXISTS disease_surveillance.Patients (
    patient_id BIGINT GENERATED ALWAYS AS IDENTITY,  -- Auto-generated sequential ID
    patient_name STRING,                             -- Full name of the patient
    dob DATE,                                        -- Date of birth
    gender STRING,                                   -- Gender of the patient
    zipcode STRING,                                  -- Zipcode of the patient
    region_id BIGINT                                 -- Foreign key linking to Regions table
)
USING DELTA
PARTITIONED BY (zipcode);

-- Optimize the Patients table for query performance
OPTIMIZE disease_surveillance.Patients
ZORDER BY (patient_name);

-- Cache the Patients table
CACHE TABLE disease_surveillance.Patients;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Create the Diseases table
CREATE TABLE IF NOT EXISTS disease_surveillance.Diseases (
    disease_id BIGINT GENERATED ALWAYS AS IDENTITY,  -- Auto-generated unique ID
    disease_name STRING NOT NULL,                    -- Name of the disease
    description STRING                               -- Short description of the disease
)
USING DELTA;

-- Optimize the Diseases table for query performance
OPTIMIZE disease_surveillance.Diseases
ZORDER BY (disease_name);

-- Cache the Diseases table
CACHE TABLE disease_surveillance.Diseases;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Create the Cases table
CREATE TABLE IF NOT EXISTS disease_surveillance.Cases (
    case_id BIGINT GENERATED ALWAYS AS IDENTITY,    -- Auto-generated unique ID
    patient_id BIGINT NOT NULL,                     -- Foreign key linking to Patients table
    disease_id BIGINT NOT NULL,                     -- Foreign key linking to Diseases table
    diagnosis_date DATE NOT NULL,                   -- Date the disease was diagnosed
    severity STRING,                                -- Severity of the case
    notes STRING                                    -- Additional information (optional)
)
USING DELTA;

-- Optimize the Cases table for query performance
OPTIMIZE disease_surveillance.Cases
ZORDER BY (diagnosis_date);

-- Cache the Cases table
CACHE TABLE disease_surveillance.Cases;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Create the Vaccines table
CREATE TABLE IF NOT EXISTS disease_surveillance.Vaccines (
    vaccine_id BIGINT GENERATED ALWAYS AS IDENTITY,  -- Auto-generated unique ID
    vaccine_name STRING NOT NULL,                    -- Name of the vaccine
    manufacturer STRING,                             -- Name of the vaccine manufacturer
    description STRING                               -- Short description of the vaccine
)
USING DELTA;

-- Optimize the Vaccines table for query performance
OPTIMIZE disease_surveillance.Vaccines
ZORDER BY (vaccine_name);

-- Cache the Vaccines table
CACHE TABLE disease_surveillance.Vaccines;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Create the VaccineDiseases table (join table)
CREATE TABLE IF NOT EXISTS disease_surveillance.VaccineDiseases (
    vaccine_id BIGINT NOT NULL,                      -- Foreign key linking to Vaccines table
    disease_id BIGINT NOT NULL,                      -- Foreign key linking to Diseases table
    PRIMARY KEY (vaccine_id, disease_id)             -- Composite primary key
)
USING DELTA;

-- Optimize the VaccineDiseases table for query performance
OPTIMIZE disease_surveillance.VaccineDiseases
ZORDER BY (vaccine_id);

-- Cache the VaccineDiseases table
CACHE TABLE disease_surveillance.VaccineDiseases;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Create the Immunizations table
CREATE TABLE IF NOT EXISTS disease_surveillance.Immunizations (
    immunization_id BIGINT GENERATED ALWAYS AS IDENTITY,  -- Auto-generated unique ID
    patient_id BIGINT NOT NULL,                           -- Foreign key linking to Patients table
    vaccine_id BIGINT NOT NULL,                           -- Foreign key linking to Vaccines table
    immunization_date DATE NOT NULL,                      -- Date the vaccine was administered
    administered_by STRING                                -- Name of the healthcare provider (optional)
)
USING DELTA;

-- Optimize the Immunizations table for query performance
OPTIMIZE disease_surveillance.Immunizations
ZORDER BY (immunization_date);

-- Cache the Immunizations table
CACHE TABLE disease_surveillance.Immunizations;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Create the Regions table
CREATE TABLE IF NOT EXISTS disease_surveillance.Regions (
    region_id BIGINT GENERATED ALWAYS AS IDENTITY,  -- Auto-generated unique ID
    region_name STRING NOT NULL,                   -- Name of the region (e.g., "Manhattan")
    zipcode STRING                                 -- Zipcode associated with the region
)
USING DELTA
PARTITIONED BY (zipcode);

-- Optimize the Regions table for query performance
OPTIMIZE disease_surveillance.Regions
ZORDER BY (region_name);

-- Cache the Regions table
CACHE TABLE disease_surveillance.Regions;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
show tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>disease_surveillance</td><td>cases</td><td>false</td></tr><tr><td>disease_surveillance</td><td>diseases</td><td>false</td></tr><tr><td>disease_surveillance</td><td>immunizations</td><td>false</td></tr><tr><td>disease_surveillance</td><td>patients</td><td>false</td></tr><tr><td>disease_surveillance</td><td>regions</td><td>false</td></tr><tr><td>disease_surveillance</td><td>vaccinediseases</td><td>false</td></tr><tr><td>disease_surveillance</td><td>vaccines</td><td>false</td></tr><tr><td></td><td>_sqldf</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
-- Insert data into the Diseases table
INSERT INTO disease_surveillance.Diseases (disease_name, description)
VALUES
    ('Measles', 'A highly contagious viral disease'),
    ('Mumps', 'A viral disease causing swelling of salivary glands'),
    ('Rubella', 'A contagious viral disease also known as German measles'),
    ('Influenza', 'A viral infection causing fever, chills, and muscle pain'),
    ('COVID-19', 'A respiratory disease caused by the SARS-CoV-2 virus');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %%
# %sql

select * from diseases
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>disease_id</th><th>disease_name</th><th>description</th></tr></thead><tbody><tr><td>1</td><td>Measles</td><td>A highly contagious viral disease</td></tr><tr><td>2</td><td>Mumps</td><td>A viral disease causing swelling of salivary glands</td></tr><tr><td>3</td><td>Rubella</td><td>A contagious viral disease also known as German measles</td></tr><tr><td>4</td><td>Influenza</td><td>A viral infection causing fever, chills, and muscle pain</td></tr><tr><td>5</td><td>COVID-19</td><td>A respiratory disease caused by the SARS-CoV-2 virus</td></tr></tbody></table></div>

# %%
# %sql
-- Insert data into the Vaccines table
INSERT INTO disease_surveillance.Vaccines (vaccine_name, manufacturer, description)
VALUES
    ('MMR', 'PharmaCo', 'A vaccine for Measles, Mumps, and Rubella'),
    ('Flu Shot', 'VaxCorp', 'Annual vaccine for influenza'),
    ('Pfizer-BioNTech', 'Pfizer', 'COVID-19 mRNA vaccine'),
    ('Moderna', 'Moderna', 'COVID-19 mRNA vaccine'),
    ('Johnson & Johnson', 'Janssen', 'COVID-19 viral vector vaccine');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM disease_surveillance.Vaccines;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vaccine_id</th><th>vaccine_name</th><th>manufacturer</th><th>description</th></tr></thead><tbody><tr><td>1</td><td>MMR</td><td>PharmaCo</td><td>A vaccine for Measles, Mumps, and Rubella</td></tr><tr><td>2</td><td>Flu Shot</td><td>VaxCorp</td><td>Annual vaccine for influenza</td></tr><tr><td>3</td><td>Pfizer-BioNTech</td><td>Pfizer</td><td>COVID-19 mRNA vaccine</td></tr><tr><td>4</td><td>Moderna</td><td>Moderna</td><td>COVID-19 mRNA vaccine</td></tr><tr><td>5</td><td>Johnson & Johnson</td><td>Janssen</td><td>COVID-19 viral vector vaccine</td></tr></tbody></table></div>

# %%
# %sql
-- Insert data into the VaccineDiseases table
INSERT INTO disease_surveillance.VaccineDiseases (vaccine_id, disease_id)
VALUES
    (1, 1),  -- MMR targets Measles
    (1, 2),  -- MMR targets Mumps
    (1, 3),  -- MMR targets Rubella
    (2, 4),  -- Flu Shot targets Influenza
    (3, 5),  -- Pfizer-BioNTech targets COVID-19
    (4, 5),  -- Moderna targets COVID-19
    (5, 5);  -- Johnson & Johnson targets COVID-19
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>7</td><td>7</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM disease_surveillance.VaccineDiseases;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vaccine_id</th><th>disease_id</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr><tr><td>1</td><td>2</td></tr><tr><td>1</td><td>3</td></tr><tr><td>2</td><td>4</td></tr><tr><td>3</td><td>5</td></tr><tr><td>4</td><td>5</td></tr><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
-- Insert data into the Regions table
INSERT INTO disease_surveillance.Regions (region_name, zipcode)
VALUES
    ('Manhattan', '10001'),
    ('Brooklyn', '11201'),
    ('Queens', '11373'),
    ('Bronx', '10451'),
    ('Staten Island', '10301');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %%
# %sql 
select * from regions
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region_id</th><th>region_name</th><th>zipcode</th></tr></thead><tbody><tr><td>5</td><td>Staten Island</td><td>10301</td></tr><tr><td>1</td><td>Manhattan</td><td>10001</td></tr><tr><td>2</td><td>Brooklyn</td><td>11201</td></tr><tr><td>3</td><td>Queens</td><td>11373</td></tr><tr><td>4</td><td>Bronx</td><td>10451</td></tr></tbody></table></div>

# %% [markdown]
# 1. List All Vaccines and the Diseases They Target

# %%
# %sql
SELECT 
    v.vaccine_name AS Vaccine,
    d.disease_name AS Disease
FROM 
    disease_surveillance.VaccineDiseases vd
JOIN 
    disease_surveillance.Vaccines v ON vd.vaccine_id = v.vaccine_id
JOIN 
    disease_surveillance.Diseases d ON vd.disease_id = d.disease_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Vaccine</th><th>Disease</th></tr></thead><tbody><tr><td>MMR</td><td>Rubella</td></tr><tr><td>Flu Shot</td><td>Influenza</td></tr><tr><td>Pfizer-BioNTech</td><td>COVID-19</td></tr><tr><td>Moderna</td><td>COVID-19</td></tr><tr><td>Johnson & Johnson</td><td>COVID-19</td></tr><tr><td>MMR</td><td>Mumps</td></tr><tr><td>MMR</td><td>Measles</td></tr></tbody></table></div>

# %% [markdown]
# 2. List All Diseases and Their Corresponding Vaccines
# (Similar to the query above, but focused on diseases first.)

# %%
# %sql
SELECT 
    d.disease_name AS Disease,
    v.vaccine_name AS Vaccine
FROM 
    disease_surveillance.VaccineDiseases vd
JOIN 
    disease_surveillance.Diseases d ON vd.disease_id = d.disease_id
JOIN 
    disease_surveillance.Vaccines v ON vd.vaccine_id = v.vaccine_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Disease</th><th>Vaccine</th></tr></thead><tbody><tr><td>Measles</td><td>MMR</td></tr><tr><td>Mumps</td><td>MMR</td></tr><tr><td>Rubella</td><td>MMR</td></tr><tr><td>Influenza</td><td>Flu Shot</td></tr><tr><td>COVID-19</td><td>Johnson & Johnson</td></tr><tr><td>COVID-19</td><td>Moderna</td></tr><tr><td>COVID-19</td><td>Pfizer-BioNTech</td></tr></tbody></table></div>

# %% [markdown]
# 3. Find Diseases Without Any Vaccines

# %%
# %sql
SELECT 
    d.disease_name AS Disease
FROM 
    disease_surveillance.Diseases d
LEFT JOIN 
    disease_surveillance.VaccineDiseases vd ON d.disease_id = vd.disease_id
WHERE 
    vd.vaccine_id IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Disease</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# 4. Find Vaccines Without Any Associated Diseases

# %%
# %sql
SELECT 
    v.vaccine_name AS Vaccine
FROM 
    disease_surveillance.Vaccines v
LEFT JOIN 
    disease_surveillance.VaccineDiseases vd ON v.vaccine_id = vd.vaccine_id
WHERE 
    vd.disease_id IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Vaccine</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# 5. Count How Many Diseases Each Vaccine Targets

# %%
# %sql
SELECT 
    v.vaccine_name AS Vaccine,
    COUNT(vd.disease_id) AS Disease_Count
FROM 
    disease_surveillance.VaccineDiseases vd
JOIN 
    disease_surveillance.Vaccines v ON vd.vaccine_id = v.vaccine_id
GROUP BY 
    v.vaccine_name;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Vaccine</th><th>Disease_Count</th></tr></thead><tbody><tr><td>Johnson & Johnson</td><td>1</td></tr><tr><td>Moderna</td><td>1</td></tr><tr><td>Pfizer-BioNTech</td><td>1</td></tr><tr><td>Flu Shot</td><td>1</td></tr><tr><td>MMR</td><td>3</td></tr></tbody></table></div>

# %% [markdown]
# 6. Count How Many Vaccines Exist for Each Disease

# %%
# %sql
SELECT 
    d.disease_name AS Disease,
    COUNT(vd.vaccine_id) AS Vaccine_Count
FROM 
    disease_surveillance.VaccineDiseases vd
JOIN 
    disease_surveillance.Diseases d ON vd.disease_id = d.disease_id
GROUP BY 
    d.disease_name;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Disease</th><th>Vaccine_Count</th></tr></thead><tbody><tr><td>Rubella</td><td>1</td></tr><tr><td>COVID-19</td><td>3</td></tr><tr><td>Measles</td><td>1</td></tr><tr><td>Mumps</td><td>1</td></tr><tr><td>Influenza</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# 7. Get a Detailed Report of Vaccines, Their Manufacturers, and the Diseases They Target

# %%
# %sql
SELECT 
    v.vaccine_name AS Vaccine,
    v.manufacturer AS Manufacturer,
    d.disease_name AS Disease
FROM 
    disease_surveillance.VaccineDiseases vd
JOIN 
    disease_surveillance.Vaccines v ON vd.vaccine_id = v.vaccine_id
JOIN 
    disease_surveillance.Diseases d ON vd.disease_id = d.disease_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Vaccine</th><th>Manufacturer</th><th>Disease</th></tr></thead><tbody><tr><td>MMR</td><td>PharmaCo</td><td>Rubella</td></tr><tr><td>Flu Shot</td><td>VaxCorp</td><td>Influenza</td></tr><tr><td>Pfizer-BioNTech</td><td>Pfizer</td><td>COVID-19</td></tr><tr><td>Moderna</td><td>Moderna</td><td>COVID-19</td></tr><tr><td>Johnson & Johnson</td><td>Janssen</td><td>COVID-19</td></tr><tr><td>MMR</td><td>PharmaCo</td><td>Mumps</td></tr><tr><td>MMR</td><td>PharmaCo</td><td>Measles</td></tr></tbody></table></div>

# %% [markdown]
# 8. List All Vaccines That Target COVID-19

# %%
# %sql
SELECT 
    v.vaccine_name AS Vaccine
FROM 
    disease_surveillance.VaccineDiseases vd
JOIN 
    disease_surveillance.Vaccines v ON vd.vaccine_id = v.vaccine_id
JOIN 
    disease_surveillance.Diseases d ON vd.disease_id = d.disease_id
WHERE 
    d.disease_name = 'COVID-19';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Vaccine</th></tr></thead><tbody><tr><td>Pfizer-BioNTech</td></tr><tr><td>Moderna</td></tr><tr><td>Johnson & Johnson</td></tr></tbody></table></div>

# %% [markdown]
# 9. List All Diseases Targeted by the MMR Vaccine

# %%
# %sql
SELECT 
    d.disease_name AS Disease
FROM 
    disease_surveillance.VaccineDiseases vd
JOIN 
    disease_surveillance.Vaccines v ON vd.vaccine_id = v.vaccine_id
JOIN 
    disease_surveillance.Diseases d ON vd.disease_id = d.disease_id
WHERE 
    v.vaccine_name = 'MMR';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Disease</th></tr></thead><tbody><tr><td>Rubella</td></tr><tr><td>Mumps</td></tr><tr><td>Measles</td></tr></tbody></table></div>

# %% [markdown]
# 10. Check for Any Duplicate Entries in VaccineDiseases

# %%
# %sql
SELECT 
    vaccine_id, 
    disease_id, 
    COUNT(*) AS Entry_Count
FROM 
    disease_surveillance.VaccineDiseases
GROUP BY 
    vaccine_id, disease_id
HAVING 
    COUNT(*) > 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vaccine_id</th><th>disease_id</th><th>Entry_Count</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# 11. Verify the Total Number of Vaccines and Diseases
# (For quick verification of table population.)

# %%
# %sql
-- Count total vaccines
SELECT COUNT(*) AS Total_Vaccines FROM disease_surveillance.Vaccines;

-- Count total diseases
SELECT COUNT(*) AS Total_Diseases FROM disease_surveillance.Diseases;

-- Count total vaccine-disease relationships
SELECT COUNT(*) AS Total_Vaccine_Disease_Relationships FROM disease_surveillance.VaccineDiseases;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total_Vaccine_Disease_Relationships</th></tr></thead><tbody><tr><td>7</td></tr></tbody></table></div>

# %% [markdown]
# 12. Verify That Every Disease in VaccineDiseases Exists in the Diseases Table

# %%
# %sql
SELECT 
    vd.disease_id
FROM 
    disease_surveillance.VaccineDiseases vd
LEFT JOIN 
    disease_surveillance.Diseases d ON vd.disease_id = d.disease_id
WHERE 
    d.disease_id IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>disease_id</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# 13. Verify That Every Vaccine in VaccineDiseases Exists in the Vaccines Table

# %%
# %sql
SELECT 
    vd.vaccine_id
FROM 
    disease_surveillance.VaccineDiseases vd
LEFT JOIN 
    disease_surveillance.Vaccines v ON vd.vaccine_id = v.vaccine_id
WHERE 
    v.vaccine_id IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vaccine_id</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE TABLE disease_surveillance.immunizations;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>immunization_id</td><td>bigint</td><td>null</td></tr><tr><td>patient_id</td><td>bigint</td><td>null</td></tr><tr><td>vaccine_id</td><td>bigint</td><td>null</td></tr><tr><td>immunization_date</td><td>date</td><td>null</td></tr><tr><td>administered_by</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
select * from patients
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>patient_id</th><th>patient_name</th><th>dob</th><th>gender</th><th>zipcode</th><th>region_id</th></tr></thead><tbody><tr><td>17</td><td>Bobby Ponce</td><td>1985-12-07</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>28</td><td>Emily Cook</td><td>1961-04-26</td><td>Male</td><td>46958</td><td>null</td></tr><tr><td>61</td><td>Jamie Carrillo</td><td>1997-12-20</td><td>Male</td><td>46958</td><td>null</td></tr><tr><td>85</td><td>Jenna Sullivan</td><td>1944-07-21</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>90</td><td>Brian Newman</td><td>1972-01-21</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>125</td><td>Destiny Williams</td><td>2002-01-11</td><td>Male</td><td>46958</td><td>null</td></tr><tr><td>190</td><td>Jeffery Moss</td><td>2013-03-05</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>268</td><td>Maria Ramirez</td><td>2023-04-17</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>286</td><td>Zachary Shea</td><td>1954-07-15</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>313</td><td>Carolyn Nguyen</td><td>1975-09-16</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>354</td><td>Cathy Cruz</td><td>2014-08-20</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>364</td><td>Alyssa Moore</td><td>1979-10-14</td><td>Male</td><td>46958</td><td>null</td></tr><tr><td>378</td><td>Michael Burns</td><td>1974-01-08</td><td>Male</td><td>46958</td><td>null</td></tr><tr><td>389</td><td>Austin Davis</td><td>1989-04-22</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>445</td><td>Albert Mccullough</td><td>2007-02-14</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>455</td><td>Jennifer York</td><td>2021-03-11</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>470</td><td>Ashley Nguyen</td><td>1988-09-18</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>498</td><td>Mary Lane</td><td>1951-10-24</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>499</td><td>Lauren Rivera</td><td>1948-04-01</td><td>Male</td><td>46958</td><td>null</td></tr><tr><td>505</td><td>Jessica Parker</td><td>2020-02-22</td><td>Male</td><td>46958</td><td>null</td></tr><tr><td>516</td><td>David Walker</td><td>2016-09-15</td><td>Male</td><td>46958</td><td>null</td></tr><tr><td>528</td><td>Jennifer Russell</td><td>1952-05-07</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>615</td><td>Dalton Clark</td><td>1976-09-12</td><td>Male</td><td>46958</td><td>null</td></tr><tr><td>635</td><td>Timothy Mcdonald</td><td>1990-07-06</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>649</td><td>Paul Matthews</td><td>1985-02-18</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>655</td><td>Claudia Perez</td><td>1986-12-12</td><td>Male</td><td>46958</td><td>null</td></tr><tr><td>737</td><td>Glen Thomas</td><td>2010-09-05</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>756</td><td>James Peters</td><td>2004-02-22</td><td>Female</td><td>46958</td><td>null</td></tr><tr><td>767</td><td>Hannah Brown</td><td>2012-09-10</td><td>Male</td><td>46958</td><td>null</td></tr><tr><td>826</td><td>Michelle Evans</td><td>1972-10-10</td><td>Male</td><td>46958</td><td>null</td></tr><tr><td>849</td><td>Lori Wagner</td><td>1934-11-08</td><td>Male</td><td>46958</td><td>null</td></tr><tr><td>134</td><td>Laura Burke</td><td>2017-12-20</td><td>Female</td><td>57429</td><td>null</td></tr><tr><td>145</td><td>Benjamin Edwards</td><td>2019-03-08</td><td>Female</td><td>57429</td><td>null</td></tr><tr><td>194</td><td>Vanessa Allison</td><td>1962-04-16</td><td>Female</td><td>57429</td><td>null</td></tr><tr><td>457</td><td>Danielle Griffin</td><td>2020-10-31</td><td>Male</td><td>57429</td><td>null</td></tr><tr><td>496</td><td>Michael Santiago</td><td>2012-12-21</td><td>Male</td><td>57429</td><td>null</td></tr><tr><td>545</td><td>Shelly Bond</td><td>1962-12-12</t ...

# %%
# %sql
select * from cases
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>case_id</th><th>patient_id</th><th>disease_id</th><th>diagnosis_date</th><th>severity</th><th>notes</th></tr></thead><tbody><tr><td>1</td><td>7</td><td>2</td><td>2024-11-24</td><td>Severe</td><td>null</td></tr><tr><td>2</td><td>9</td><td>1</td><td>2024-11-01</td><td>Mild</td><td>null</td></tr><tr><td>3</td><td>10</td><td>5</td><td>2024-11-04</td><td>Mild</td><td>kjshdgh</td></tr><tr><td>4</td><td>11</td><td>4</td><td>2024-11-01</td><td>Severe</td><td>null</td></tr><tr><td>5</td><td>12</td><td>1</td><td>2011-11-11</td><td>Mild</td><td>kjsdhgkjhdgkjn</td></tr><tr><td>6</td><td>13</td><td>4</td><td>2024-11-03</td><td>Moderate</td><td>bkdjshgvpoeifpi hjdsgkjbg nbdnbg</td></tr><tr><td>7</td><td>532</td><td>18</td><td>2020-12-15</td><td>Severe</td><td>Place option success say prepare pick.</td></tr><tr><td>8</td><td>315</td><td>5</td><td>2021-12-25</td><td>Severe</td><td>Class eat determine open purpose.</td></tr><tr><td>9</td><td>390</td><td>18</td><td>2023-03-24</td><td>Severe</td><td>Want deep future drug.</td></tr><tr><td>10</td><td>932</td><td>8</td><td>2020-06-15</td><td>Severe</td><td>Fly nation change bring pressure half make.</td></tr><tr><td>11</td><td>130</td><td>6</td><td>2021-01-19</td><td>Moderate</td><td>Money rate feel policy.</td></tr><tr><td>12</td><td>898</td><td>17</td><td>2020-12-06</td><td>Mild</td><td>Its happy home hear many family himself.</td></tr><tr><td>13</td><td>665</td><td>7</td><td>2022-12-08</td><td>Severe</td><td>Different yes us make both sense.</td></tr><tr><td>14</td><td>142</td><td>7</td><td>2021-12-09</td><td>Severe</td><td>Way anyone successful beat animal factor.</td></tr><tr><td>15</td><td>146</td><td>14</td><td>2022-11-03</td><td>Severe</td><td>Benefit note whose black.</td></tr><tr><td>16</td><td>543</td><td>1</td><td>2023-12-17</td><td>Severe</td><td>Test claim our TV board.</td></tr><tr><td>17</td><td>398</td><td>7</td><td>2022-04-04</td><td>Severe</td><td>Somebody push movie dinner establish add on.</td></tr><tr><td>18</td><td>306</td><td>6</td><td>2020-03-20</td><td>Mild</td><td>Heavy line exist true into left by.</td></tr><tr><td>19</td><td>400</td><td>6</td><td>2023-06-27</td><td>Mild</td><td>Pull few toward ground.</td></tr><tr><td>20</td><td>547</td><td>6</td><td>2020-07-25</td><td>Moderate</td><td>Moment rule high board water form.</td></tr><tr><td>22</td><td>464</td><td>1</td><td>2021-07-12</td><td>Mild</td><td>Own picture explain serious.</td></tr><tr><td>21</td><td>563</td><td>8</td><td>2022-10-21</td><td>Mild</td><td>Nice treat decade decide right bag five.</td></tr><tr><td>23</td><td>32</td><td>20</td><td>2023-02-06</td><td>Severe</td><td>Say all newspaper sense discussion.</td></tr><tr><td>24</td><td>54</td><td>2</td><td>2021-09-03</td><td>Mild</td><td>Wish among both. Also step necessary baby.</td></tr><tr><td>25</td><td>289</td><td>16</td><td>2022-06-08</td><td>Moderate</td><td>Responsibility into situation become.</td></tr><tr><td>26</td><td>20</td><td>13</td><td>2023-06-12</td><td>Severe</td><td>Mrs he away day.</td></tr><tr><td>27</td><td>489</td><td>20</td><td>2021-03-23</td><td>Severe</td><td>Across listen last glass.</td></tr><tr><td>28</td><td>280</td><td>11</td><td>2023-02-26</td><td>Severe</td><td>Number actually memory side ground.</td></tr><tr><td>29</td><td>886</td><td>3</td><td>2020-09-24</td><td>Severe</td><td>By drop follow without center.</td></tr><tr><td>30</td><td>352</td><td>16</td><td>2022-04-30</td><td>Moderate</td><td>Cause before loss election fish simple attorney.</td></tr><tr><td>31</td><td>523</td><td>1</td><td>2021-01-10</td><td>Mild</td><td>Sing produce not attorney specific.</td></tr><tr><td>32</td><td>715</td><td>17</td><td>2022-07-02</td><td>Mild</td><td>Serious high right practice break.</td></tr><tr><td>33</td><td>421</td><td>20</td><td>2023-05-30</td><td>Moderate</td><td>Here happen school after whatever wear may.</td></tr ...

# %%
# %sql
select * from immunizations
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>immunization_id</th><th>patient_id</th><th>vaccine_id</th><th>immunization_date</th><th>administered_by</th></tr></thead><tbody><tr><td>1</td><td>9</td><td>1</td><td>2024-11-10</td><td>John</td></tr><tr><td>2</td><td>11</td><td>4</td><td>2024-10-03</td><td>kjkjhkgggo</td></tr><tr><td>3</td><td>12</td><td>1</td><td>2018-11-24</td><td>mnbmnjshdg</td></tr><tr><td>4</td><td>13</td><td>3</td><td>2024-11-04</td><td>pppppppp</td></tr><tr><td>5</td><td>395</td><td>10</td><td>2022-11-18</td><td>Sara Downs</td></tr><tr><td>6</td><td>394</td><td>1</td><td>2021-01-24</td><td>Garrett Norton</td></tr><tr><td>7</td><td>21</td><td>4</td><td>2023-01-18</td><td>Kevin Fleming</td></tr><tr><td>8</td><td>210</td><td>3</td><td>2021-12-20</td><td>Jessica Miller</td></tr><tr><td>9</td><td>686</td><td>3</td><td>2022-09-23</td><td>Patricia Bautista</td></tr><tr><td>10</td><td>648</td><td>6</td><td>2021-05-21</td><td>Carmen Wright</td></tr><tr><td>11</td><td>581</td><td>2</td><td>2021-05-27</td><td>Jose Williams</td></tr><tr><td>12</td><td>272</td><td>10</td><td>2021-11-02</td><td>Cameron Vasquez</td></tr><tr><td>13</td><td>134</td><td>5</td><td>2023-02-07</td><td>Jonathan Harrison</td></tr><tr><td>15</td><td>501</td><td>10</td><td>2022-10-01</td><td>Haley Herrera</td></tr><tr><td>14</td><td>534</td><td>5</td><td>2023-03-22</td><td>Anthony Garcia</td></tr><tr><td>16</td><td>765</td><td>8</td><td>2023-10-19</td><td>Andrew Edwards</td></tr><tr><td>17</td><td>540</td><td>5</td><td>2023-02-09</td><td>Mindy Hardy</td></tr><tr><td>18</td><td>938</td><td>3</td><td>2023-03-17</td><td>Jacob Reyes</td></tr><tr><td>19</td><td>611</td><td>3</td><td>2022-02-20</td><td>Mark Anderson</td></tr><tr><td>20</td><td>382</td><td>8</td><td>2022-09-12</td><td>Krista Gonzalez</td></tr><tr><td>21</td><td>102</td><td>5</td><td>2020-09-24</td><td>Lynn Walker</td></tr><tr><td>22</td><td>449</td><td>3</td><td>2020-12-17</td><td>David Brooks</td></tr><tr><td>23</td><td>847</td><td>2</td><td>2022-07-08</td><td>Justin Farrell</td></tr><tr><td>24</td><td>892</td><td>1</td><td>2023-08-20</td><td>Justin Hunt</td></tr><tr><td>25</td><td>249</td><td>10</td><td>2020-03-06</td><td>Cindy Harris</td></tr><tr><td>26</td><td>983</td><td>1</td><td>2022-08-26</td><td>Alexandra Fletcher</td></tr><tr><td>27</td><td>460</td><td>2</td><td>2021-09-19</td><td>James Webb</td></tr><tr><td>29</td><td>99</td><td>8</td><td>2020-02-25</td><td>John Wilson</td></tr><tr><td>28</td><td>784</td><td>4</td><td>2020-08-16</td><td>Dana Matthews</td></tr><tr><td>30</td><td>498</td><td>7</td><td>2020-01-10</td><td>Louis Luna</td></tr><tr><td>31</td><td>678</td><td>6</td><td>2022-03-19</td><td>Brittany Ford</td></tr><tr><td>32</td><td>749</td><td>5</td><td>2020-01-24</td><td>Gregory Jones</td></tr><tr><td>33</td><td>539</td><td>4</td><td>2020-07-21</td><td>Joel Galvan</td></tr><tr><td>34</td><td>331</td><td>7</td><td>2023-01-10</td><td>Natalie West</td></tr><tr><td>35</td><td>938</td><td>5</td><td>2023-04-17</td><td>George Wright</td></tr><tr><td>37</td><td>373</td><td>10</td><td>2022-11-09</td><td>Amanda Murillo</td></tr><tr><td>36</td><td>862</td><td>7</td><td>2022-03-01</td><td>Rachel Sanchez</td></tr><tr><td>38</td><td>373</td><td>1</td><td>2020-08-22</td><td>Jose Dickson</td></tr><tr><td>39</td><td>815</td><td>10</td><td>2020-03-12</td><td>Deborah Hunt</td></tr><tr><td>41</td><td>320</td><td>4</td><td>2021-01-30</td><td>Gerald Solomon</td></tr><tr><td>40</td><td>447</td><td>4</td><td>2021-03-15</td><td>Jacob Cannon DVM</td></tr><tr><td>42</td><td>65</td><td>8</td><td>2021-06-07</td><td>Dominic Gross</td></tr><tr><td>43</td><td>446</td><td>1</td><td>2020-08-25</td><td>Sheila Daugherty</td></tr><tr><td>45</td><td>321</td><td>8</td><td>2023-04-24</td><td>Rhonda Gray</td></tr><tr><td>44</td><td>186</td><td>2</td><td>2023-02-26</td><td>Daniel Riley</td></tr><tr><td>46</td><td>136</td><td>5</td><td>2021-1 ...

# %%
# %sql
SELECT * FROM disease_surveillance.Regions;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region_id</th><th>region_name</th><th>zipcode</th></tr></thead><tbody><tr><td>29</td><td>Lake Cassandrashire</td><td>83256</td></tr><tr><td>19</td><td>Lake Nathanielview</td><td>71641</td></tr><tr><td>43</td><td>South Michaelmouth</td><td>78953</td></tr><tr><td>31</td><td>East Jameschester</td><td>84855</td></tr><tr><td>41</td><td>South Thomasshire</td><td>49750</td></tr><tr><td>14</td><td>North Kennethtown</td><td>21838</td></tr><tr><td>36</td><td>North Connieland</td><td>38589</td></tr><tr><td>10</td><td>East Shellyshire</td><td>09273</td></tr><tr><td>51</td><td>Lake Josephshire</td><td>03234</td></tr><tr><td>34</td><td>East Natashafort</td><td>33512</td></tr><tr><td>13</td><td>West Megantown</td><td>45555</td></tr><tr><td>9</td><td>Port Larryport</td><td>46958</td></tr><tr><td>55</td><td>West Elizabeth</td><td>59037</td></tr><tr><td>16</td><td>Cassandramouth</td><td>57429</td></tr><tr><td>28</td><td>South Patricia</td><td>44822</td></tr><tr><td>50</td><td>Lake Christian</td><td>44394</td></tr><tr><td>39</td><td>Port Amberbury</td><td>09848</td></tr><tr><td>38</td><td>Port Adammouth</td><td>72026</td></tr><tr><td>24</td><td>Stevensonberg</td><td>41430</td></tr><tr><td>48</td><td>South Deborah</td><td>34369</td></tr><tr><td>12</td><td>East Jennifer</td><td>89978</td></tr><tr><td>20</td><td>Thompsonshire</td><td>45657</td></tr><tr><td>40</td><td>Millerborough</td><td>69201</td></tr><tr><td>22</td><td>Christinaview</td><td>46948</td></tr><tr><td>7</td><td>Lake Michele</td><td>83077</td></tr><tr><td>45</td><td>Wheelerburgh</td><td>37541</td></tr><tr><td>17</td><td>Port Latasha</td><td>49164</td></tr><tr><td>53</td><td>Reyesborough</td><td>79380</td></tr><tr><td>26</td><td>Bryanborough</td><td>33975</td></tr><tr><td>44</td><td>North Edward</td><td>11220</td></tr><tr><td>11</td><td>Kimberlytown</td><td>36781</td></tr><tr><td>52</td><td>South Ashley</td><td>43941</td></tr><tr><td>54</td><td>North Krista</td><td>83543</td></tr><tr><td>37</td><td>North Megan</td><td>58309</td></tr><tr><td>21</td><td>Rebeccafurt</td><td>32057</td></tr><tr><td>18</td><td>Deniseville</td><td>13476</td></tr><tr><td>25</td><td>North Erica</td><td>49828</td></tr><tr><td>33</td><td>Jacobsmouth</td><td>84010</td></tr><tr><td>49</td><td>Reginafort</td><td>30594</td></tr><tr><td>46</td><td>Jacobport</td><td>92531</td></tr><tr><td>47</td><td>Brownport</td><td>75293</td></tr><tr><td>42</td><td>Jesseland</td><td>14178</td></tr><tr><td>27</td><td>Lanehaven</td><td>86781</td></tr><tr><td>30</td><td>Mariastad</td><td>45380</td></tr><tr><td>6</td><td>Kathystad</td><td>77511</td></tr><tr><td>32</td><td>Jamesview</td><td>51402</td></tr><tr><td>15</td><td>Johnhaven</td><td>22576</td></tr><tr><td>35</td><td>New Eric</td><td>74603</td></tr><tr><td>8</td><td>Lake Lee</td><td>45585</td></tr><tr><td>23</td><td>Kimside</td><td>80466</td></tr><tr><td>5</td><td>Staten Island</td><td>10301</td></tr><tr><td>1</td><td>Manhattan</td><td>10001</td></tr><tr><td>2</td><td>Brooklyn</td><td>11201</td></tr><tr><td>3</td><td>Queens</td><td>11373</td></tr><tr><td>4</td><td>Bronx</td><td>10451</td></tr></tbody></table></div>
